# %% [markdown]
# Considero que no mínimo a informação venha próxima do que foi tratado até aqui, aqui iremos fazer algumas limpezas e tratamento o mesmo que utilizaremos para novos dados.

# %%
import pandas as pd
import re
import sys
sys.path.append('../')
from toolbox import text_preprocess as tp

# %%
df = pd.read_csv('../elt/super_wine_set.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1968 entries, 0 to 1967
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vinho                    1968 non-null   object
#  1   preço                    1968 non-null   float64
#  2   comentário_do_sommelier  1968 non-null   object
#  3   uva                      1968 non-null   object
#  4   país                     1968 non-null   object
#  5   região                   1968 non-null   object
#  6   classificação            1968 non-null   object
#  7   vinícola                 1968 non-null   object
#  8   teor_alcoólico           1968 non-null   object
#  9   temperatura_de_serviço   1968 non-null   object
#  10  olfativo                 1968 non-null   object
#  11  visual                   1968 non-null   object
#  12  gustativo                1968 non-null   object
#  13  harmonização             1968 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 215.4+ KB

# %%
df
# Out:
#                                                   vinho   preço  \
# 0                           Arya Tinto 2021 Lata 269 mL   23.41
# 1                            Arya Rosé 2021 Lata 269 mL   23.41
# 2                  Paine Cabernet Sauvignon 2021 375 mL   32.82
# 3            Viña Carrasco D.O. Valle Central Rosé 2021   38.71
# 4                       Pueblo del Sol Tannat Rosé 2021   46.94
# ...                                                 ...     ...
# 1963  Espumante Brasileiro Prosecco Brut AURORA Garr...   49.99
# 1964  Vinho Espumante Brasileiro TERRANOVA Moscatel ...   49.99
# 1965  Vinho Espumante Nacional CLUB DES SOMMELIERS M...   39.99
# 1966  Champagne Francês Branco Brut Veuve Clicquot P...  499.99
# 1967  Vinho Espumante Pinot Noir CLUB DES SOMMELIERS...   66.99
#
#                                 comentário_do_sommelier  \
# 0     O Arya acaba de vez com qualquer preconceito q...
# 1     Um rosé produzido com uvas da Serra Gaúcha e d...
# 2     Essencialmente frutado e leve, este vinho foi ...
# 3     A Cabernet Sauvignon e Merlot são as uvas pres...
# 4     Um rosé do Uruguai elaborado com a emblemática...
# ...                                                 ...
# 1963                               Uma jóia brasileira.
# 1964  Espumante natural elaborado, pelo processo ita...
# 1965              Um grande ícone dos espumantes doces!
# 1966  "Veuve Clicquot Brut é o símbolo da arte da co...
# 1967  Uma raridade e uma ousadia: a grande essência ...
#
#                                                     uva      país  \
# 0     Merlot, Pinot Noir, Cabernet Franc e Cabernet ...   Brasil
# 1                         Pinot Noir, Merlot, Trebbiano   Brasil
# 2                                    Cabernet Sauvignon    Chile
# 3                            Cabernet Sauvignon, Merlot    Chile
# 4                                                Tannat  Uruguai
# ...                                                 ...       ...
# 1963                                      100% Prosecco    Brasil
# 1964                                           Moscatel    Brasil
# 1965                                            Moscato    Brasil
# 1966               Pinot Noir  Pinot Meunier Chardonnay   França
# 1967                                         Pinot Noir    Brasil
#
#                      região classificação             vinícola teor_alcoólico  \
# 0              Serra Gaúcha          Seco           Arya Wines           12.5
# 1              Serra Gaúcha          Seco           Arya Wines           11.0
# 2             Valle Central          Seco            VyF Wines           13.0
# 3             Valle Central          Seco  Luis Felipe Edwards           12.0
# 4                 Canelones          Seco       Pueblo del Sol           12.0
# ...                     ...           ...                  ...            ...
# 1963           Serra gaúcha         Tinto      Vinícola Aurora           11.5
# 1964  vale do São Francisco     Espumante                Miolo              8
# 1965      Rio Grande do Sul     Espumante      Vinícola Salton              8
# 1966     Reims - Champagne      Champagne       Veuve Clicquot             12
# 1967      Rio Grande do Sul     Espumante      Vinícola Aurora             12
#
#      temperatura_de_serviço  \
# 0                        15
# 1                         8
# 2                        16
# 3                         9
# 4                         9
# ...                     ...
# 1963                    6-8
# 1964                  04-06
# 1965                      6
# 1966                  08-10
# 1967                     06
#
#                                                olfativo  \
# 0     Frutado, sobretudo frutas vermelhas, ameixas e...
# 1     Frutas vermelhas, especialmente morangos madur...
# 2     Aromas de frutas negras e vermelhas, pimenta-d...
# 3     Intensos aromas de frutas vermelhas frescas, m...
# 4             Frutas vermelhas fresca, morango e cereja
# ...                                                 ...
# 1963                                  Fresco e frutado.
# 1964  Aroma intenso, fresco e típico, com notas de j...
# 1965  Apresenta aromas de flores brancas, cítricos, ...
# 1966  Aroma complexo com persistência aromática.  O ...
# 1967  Destacam-se aromas bastante frescos de amora b...
#
#                                                  visual  \
# 0                                                  Rubi
# 1                                    Rosa cereja pálido
# 2                                                  Rubi
# 3                                            Rosa-claro
# 4                                            Rosa claro
# ...                                                 ...
# 1963  Amarelo-palha claro, com tonalidades esverdeadas.
# 1964  Cor amarelo-esverdeada clara, perlage fino, in...
# 1965  Brilhante, com coloração claro esverdeada com ...
# 1966  Amarelo Dourado. Seu perlage fino e consistent...
# 1967  Apresenta coloração palha brilhante de belíssi...
#
#                                               gustativo  \
# 0     Corpo leve para médio, frutado, com frescor e ...
# 1     Fresco e delicado, suculento e frutado, cremos...
# 2     Um vinho jovem, leve, frutado com sutis notas ...
# 3     Jovem, leve, frutado, acidez agradável e refre...
# 4     Um vinho jovem, leve, frutado, macio, com acid...
# ...                                                 ...
# 1963                       Leve, de acidez equilibrada.
# 1964  Leve e doce ao paladar, com um final de boca j...
# 1965  Seu sabor é levemente ácido, equilibrado com s...
# 1966  Volumoso, complexo e  persistente. As notas fr...
# 1967  Seu paladar apresenta excelente estrutura, com...
#
#                                            harmonização
# 0     Embutidos, massas ao molho vermelho, risotos d...
# 1     Versátil, funcionando com aperitivos e entrada...
# 2     Opte por pratos mais leves, carnes magras, mol...
# 3     Espaguete com camarão, risoto de palmito com r...
# 4     Salada de frutos do mar, frango com vinagrete ...
# ...                                                 ...
# 1963  Risotos de frutos do mar, carpaccio, antepasto...
# 1964  Frutas frescas como morango, uvas, carambola, ...
# 1965  Sobremesas doces como tortas, saladas de fruta...
# 1966  O Brut é ideal para beber sozinho, mas também ...
# 1967  Paella, espaguete alla marinara, yakissoba, sa...
#
# [1968 rows x 14 columns]

# %%
#df['vinho'] = df['vinho'].apply(tp.wine_clean)
#df['vinho'] = df['vinho'].apply(tp.remove_stopwords)

df[['comentário_do_sommelier','uva','olfativo','visual','gustativo','harmonização']] = df[['comentário_do_sommelier','uva','olfativo','visual','gustativo','harmonização']].applymap(tp.remove_stopwords)

df[['país', 'região','classificação', 'vinícola']] = df[['país', 'região','classificação', 'vinícola']].applymap(tp.clean_text)

df['uva'].apply(tp.remove_stopwords)

df['teor_alcoólico'] = df['teor_alcoólico'].apply(tp.clean_teor)

df['temperatura_de_serviço'] = df['temperatura_de_serviço'].apply(tp.extract_numbers_and_average)
# Out:
# C:\Users\rodri\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
df
# Out:
#                                                   vinho   preço  \
# 0                           Arya Tinto 2021 Lata 269 mL   23.41
# 1                            Arya Rosé 2021 Lata 269 mL   23.41
# 2                  Paine Cabernet Sauvignon 2021 375 mL   32.82
# 3            Viña Carrasco D.O. Valle Central Rosé 2021   38.71
# 4                       Pueblo del Sol Tannat Rosé 2021   46.94
# ...                                                 ...     ...
# 1963  Espumante Brasileiro Prosecco Brut AURORA Garr...   49.99
# 1964  Vinho Espumante Brasileiro TERRANOVA Moscatel ...   49.99
# 1965  Vinho Espumante Nacional CLUB DES SOMMELIERS M...   39.99
# 1966  Champagne Francês Branco Brut Veuve Clicquot P...  499.99
# 1967  Vinho Espumante Pinot Noir CLUB DES SOMMELIERS...   66.99
#
#                                 comentário_do_sommelier  \
# 0     arya acaba vez qualquer preconceito ainda poss...
# 1     rosé produzido uvas serra gaúcha campanha deli...
# 2     essencialmente frutado leve vinho idealizado a...
# 3     cabernet sauvignon merlot uvas presentes neste...
# 4     rosé uruguai elaborado emblemática casta país ...
# ...                                                 ...
# 1963                                    jóia brasileira
# 1964  espumante natural elaborado processo italiano ...
# 1965                      grande ícone espumantes doces
# 1966  veuve clicquot brut símbolo arte combinação ca...
# 1967  raridade ousadia grande essência pinot noir cu...
#
#                                                     uva     país  \
# 0     merlot pinot noir cabernet franc cabernet sauv...   brasil
# 1                           pinot noir merlot trebbiano   brasil
# 2                                    cabernet sauvignon    chile
# 3                             cabernet sauvignon merlot    chile
# 4                                                tannat  uruguai
# ...                                                 ...      ...
# 1963                                           prosecco   brasil
# 1964                                           moscatel   brasil
# 1965                                            moscato   brasil
# 1966                pinot noir pinot meunier chardonnay   frança
# 1967                                         pinot noir   brasil
#
#                      região classificação             vinícola  \
# 0              serra gaúcha          seco           arya wines
# 1              serra gaúcha          seco           arya wines
# 2             valle central          seco            vyf wines
# 3             valle central          seco  luis felipe edwards
# 4                 canelones          seco       pueblo del sol
# ...                     ...           ...                  ...
# 1963           serra gaúcha         tinto      vinícola aurora
# 1964  vale do são francisco     espumante                miolo
# 1965      rio grande do sul     espumante      vinícola salton
# 1966        reims champagne     champagne       veuve clicquot
# 1967      rio grande do sul     espumante      vinícola aurora
#
#       teor_alcoólico  temperatura_de_serviço  \
# 0               12.5                    15.0
# 1               11.0                     8.0
# 2               13.0                    16.0
# 3               12.0                     9.0
# 4               12.0                     9.0
# ...              ...                     ...
# 1963            11.5                     7.0
# 1964            80.0                     5.0
# 1965            80.0                     6.0
# 1966            12.0                     9.0
# 1967            12.0                     6.0
#
#                                                olfativo  \
# 0     frutado sobretudo frutas vermelhas ameixas cer...
# 1     frutas vermelhas especialmente morangos maduro...
# 2               aromas frutas negras vermelhas herbáceo
# 3     intensos aromas frutas vermelhas frescas moran...
# 4                frutas vermelhas fresca morango cereja
# ...                                                 ...
# 1963                                     fresco frutado
# 1964  aroma intenso fresco típico notas jasmim outra...
# 1965  apresenta aromas flores brancas cítricos maçã ...
# 1966  aroma complexo persistência aromática brut ofe...
# 1967  aromas bastante frescos amora branca toque erv...
#
#                                                  visual  \
# 0                                                  rubi
# 1                                    rosa cereja pálido
# 2                                                  rubi
# 3
# 4                                            rosa claro
# ...                                                 ...
# 1963                      claro tonalidades esverdeadas
# 1964  cor clara perlage fino intenso persistente ter...
# 1965  brilhante coloração claro esverdeada grande de...
# 1966  amarelo dourado perlage fino consistente obtid...
# 1967  apresenta coloração palha brilhante belíssima ...
#
#                                               gustativo  \
# 0     corpo leve médio frutado frescor elegância not...
# 1     fresco delicado suculento frutado cremoso equi...
# 2     vinho jovem leve frutado sutis notas herbáceas...
# 3       jovem leve frutado acidez agradável refrescante
# 4     vinho jovem leve frutado macio acidez agradáve...
# ...                                                 ...
# 1963                            leve acidez equilibrada
# 1964    leve doce paladar final boca jovial refrescante
# 1965  sabor levemente ácido equilibrado sabor doce c...
# 1966  volumoso complexo persistente notas frutadas i...
# 1967  paladar apresenta excelente estrutura boa crem...
#
#                                            harmonização
# 0     embutidos massas molho vermelho risotos queijo...
# 1     versátil funcionando aperitivos entradas embut...
# 2     opte pratos leves carnes magras molhos base to...
# 3     espaguete camarão risoto palmito raspas limão ...
# 4     salada frutos mar frango vinagrete morango ris...
# ...                                                 ...
# 1963     risotos frutos mar carpaccio antepastos peixes
# 1964  frutas frescas morango uvas carambola romã aba...
# 1965  sobremesas doces tortas saladas fruta mousse p...
# 1966  brut ideal beber sozinho champagne fácil harmo...
# 1967  paella espaguete alla marinara yakissoba sashi...
#
# [1968 rows x 14 columns]

# %%
df.to_csv('../model/super_wine_set_clean.csv',index=False)
# Out:
# C:\Users\rodri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
